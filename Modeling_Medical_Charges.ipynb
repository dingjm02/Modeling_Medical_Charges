# %% [markdown]
# ### Introduction

# %% [markdown]
# #### This project aims to identify and analyze the key factors that contribute to differences in health insurance premiums. By examining variables such as age, gender, BMI, number of dependents, smoking habits, and region of residence, the analysis seeks to provide insights into how these characteristics influence costs. The ultimate goal is to better understand the determinants of insurance pricing and highlight which factors are most impactful in shaping premium variation.

# %% [markdown]
# ### Import Libraries and Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### EDA

# %%
df = pd.read_csv("/content/dataset_medicalcost.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
df['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# %% [markdown]
# ### Data Visualisations

# %%
df['sex']= label_encoder.fit_transform(df['sex'])
df['smoker']= label_encoder.fit_transform(df['smoker'])



sns.boxplot(df['charges'])
# Out:
# <Axes: ylabel='charges'>

# %%
sns.catplot(x="smoker", kind="count",hue = 'sex', palette="rainbow", data=df[(df.age == 18)])
plt.title("The number of smokers and non-smokers (18 years old)")
# Out:
# Text(0.5, 1.0, 'The number of smokers and non-smokers (18 years old)')

# %% [markdown]
# #### From the figure, we can initially observe that gender does not appear to be a determining factor in whether an individual smokes among 18-year-olds.

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for charges 18 years old smokers")
sns.boxplot(y="smoker", x="charges", data = df[(df.age == 18)] , orient="h", palette = 'pink')
# Out:
# /tmp/ipython-input-2013021872.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y="smoker", x="charges", data = df[(df.age == 18)] , orient="h", palette = 'pink')
# <Axes: title={'center': 'Box plot for charges 18 years old smokers'}, xlabel='charges', ylabel='smoker'>

# %% [markdown]
# #### For 18-year-olds, smoking is strongly associated with higher insurance charges. While non-smokers mostly have low costs with some outliers, smokers consistently show much higher and more variable charges, highlighting smoking as a key factor in determining premiums.

# %%
sns.lmplot(x="age", y="charges", hue="smoker", data=df, palette = 'inferno_r')

# %% [markdown]
# #### The figure demonstrates that both age and smoking status play significant roles in determining insurance charges. Insurance costs rise with age for all individuals, reflecting the increased health risks associated with aging. However, the effect of smoking is much more pronounced: at every age level, smokers consistently face substantially higher charges than non-smokers. This indicates that while age contributes to rising charges, smoking status is a dominant factor amplifying the overall cost.

# %%
sns.histplot(data=df,x='charges',kde=True)
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.set(style='whitegrid')
ax = sns.distplot(df['charges'], kde = True, color = 'c')
plt.title('Distribution of Charges')
# Out:
# /tmp/ipython-input-3697456241.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df['charges'], kde = True, color = 'c')
# Text(0.5, 1.0, 'Distribution of Charges')

# %%
sns.set(style='whitegrid')
ax = sns.distplot(df['charges'], kde = True, color = 'c')
plt.title('Distribution of Charges')
# Out:
# /tmp/ipython-input-3697456241.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df['charges'], kde = True, color = 'c')
# Text(0.5, 1.0, 'Distribution of Charges')

# %%
ax = sns.distplot(np.log10(df['charges']), kde = True, color = 'r' )
# Out:
# /tmp/ipython-input-782112099.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(np.log10(df['charges']), kde = True, color = 'r' )

# %%
charges = df['charges'].groupby(df['region']).sum().sort_values(ascending = True)
charges = charges.head()
sns.barplot(x=charges.index, y=charges, palette='Blues')
# Out:
# /tmp/ipython-input-1857609048.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=charges.index, y=charges, palette='Blues')
# <Axes: xlabel='region', ylabel='charges'>

# %% [markdown]
# #### From the graph, regional variation in total charges exists, but the differences are not dramatic. The southeast shows the highest overall charges (slightly above 5 million), while the southwest has the lowest (around 4 million). The northwest and northeast fall in between with only modest differences.
# #### This suggests that region might have some influence on overall charges, but the effect is relatively small compared to smoking status.

# %%
ax = sns.barplot(x='region', y='charges', hue='sex', data=df, palette='cool')

# %%
ax = sns.barplot(x='region', y='charges', hue='smoker', data=df, palette='cool')

# %%
ax = sns.barplot(x='region', y='charges', hue='children', data=df, palette='cool')

# %%
df['region']= label_encoder.fit_transform(df['region'])
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Smoking status has the strongest positive correlation with charges, suggesting that being a smoker is a major factor driving up medical expenses.
#
# Age and BMI also show moderate positive correlations with charges, indicating that older individuals and those with higher BMI tend to incur higher medical costs.
#
# Children, sex, and region exhibit very weak correlations with charges, implying limited direct impact.

# %%
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split
x = df.drop(['charges'], axis = 1)
y = df['charges']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression().fit(x_train,y_train)

y_train_pred = lr.predict(x_train)
y_test_pred = lr.predict(x_test)

print(lr.score(x_test,y_test))
# Out:
# 0.7833463107364539

# %%
from sklearn.preprocessing import PolynomialFeatures


X = df.drop(['charges','region'], axis = 1)
Y = df.charges



quad = PolynomialFeatures (degree = 2)
x_quad = quad.fit_transform(X)

X_train,X_test,Y_train,Y_test = train_test_split(x_quad,Y, random_state = 0)

plr = LinearRegression().fit(X_train,Y_train)

Y_train_pred = plr.predict(X_train)
Y_test_pred = plr.predict(X_test)

print(plr.score(X_test,Y_test))
# Out:
# 0.8849197344147233

# %%
from sklearn.model_selection import train_test_split
x = df.drop(['charges'], axis = 1)
y = df['charges']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split


models = {
    "LR": LinearRegression(),
    "RF": RandomForestRegressor(n_estimators=100, max_depth=7),
    "DT": DecisionTreeRegressor(),
    "GradientBoosting": GradientBoostingRegressor(n_estimators=100, max_depth=7),
    "KNN": KNeighborsRegressor(),
    "SVR": SVR()
}

for name, model in models.items():
    print(f'Training Model {name} \n-----------------------------------------------')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    print(f'Score is {model.score(x_test, y_test)}')


    # Use appropriate regression metrics
    print(f'Training R-squared: {r2_score(y_train, model.predict(x_train))}')
    print(f'Testing R-squared: {r2_score(y_test, y_pred)}')

    print(f'Mean Squared Error: {mean_squared_error(y_test, y_pred)}')
    print(f'Mean Absolute Error: {mean_absolute_error(y_test, y_pred)}')
# Out:
# Training Model LR
# -----------------------------------------------
# Score is 0.7833463107364539
# Training R-squared: 0.7417049283233981
# Testing R-squared: 0.7833463107364539
# Mean Squared Error: 33635210.431178406
# Mean Absolute Error: 4186.508898366433
# Training Model RF
# -----------------------------------------------
# Score is 0.8718138672885356
# Training R-squared: 0.9264546012742698
# Testing R-squared: 0.8718138672885356
# Mean Squared Error: 19900734.498290986
# Mean Absolute Error: 2477.457227153277
# Training Model DT
# -----------------------------------------------
# Score is 0.6969556237920975
# Training R-squared: 0.9983078124756305
# Testing R-squared: 0.6969556237920975
# Mean Squared Error: 47047254.99199264
# Mean Absolute Error: 3067.1523708059703
# Training Model GradientBoosting
# -----------------------------------------------
# Score is 0.8409845407627474
# Training R-squared: 0.9927812965590004
# Testing R-squared: 0.8409845407627474
# ...

# %% [markdown]
# ###Model Comparison and Overfitting Analysis
#
# The performance results show clear differences in model behavior. Linear Regression achieved balanced training and testing scores, indicating no significant overfitting. Random Forest and Gradient Boosting showed slightly higher training scores than testing scores, suggesting mild overfitting but still strong generalization ability. In contrast, the Decision Tree severely overfitted, with near-perfect training performance but much weaker testing results. Finally, KNN and SVR underfitted the data, failing to capture the underlying patterns effectively.
#
# After comparing multiple models, Random Forest was selected for further analysis.

# %%
max_depth_values = [1,2,3,4,5,6,7,8]
train_accuracy_values =[]
for max_depth_val in max_depth_values:
    model = RandomForestRegressor(max_depth=max_depth_val,random_state = 2)
    model.fit(x_train, y_train)
    y_pred =model.predict(x_train)
    acc_train=model.score(x_test,y_test)
    train_accuracy_values.append(acc_train)

train_accuracy_values
# Out:
# [0.6608048922770777,
#  0.8417933495550463,
#  0.8675746825596274,
#  0.872677170478934,
#  0.8753239247794342,
#  0.8755309603734038,
#  0.8729311378096285,
#  0.8711685231482463]

# %%
final_model = RandomForestRegressor(max_depth=6,random_state = 0)
final_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=6, random_state=0)

# %%
forest_train_pred = final_model.predict(x_train)
forest_test_pred = final_model.predict(x_test)

print('MSE train data: %.3f, MSE test data: %.3f' % (
mean_squared_error(y_train,forest_train_pred),
mean_squared_error(y_test,forest_test_pred)))
print('R2 train data: %.3f, R2 test data: %.3f' % (
r2_score(y_train,forest_train_pred),
r2_score(y_test,forest_test_pred)))
# Out:
# MSE train data: 13740918.931, MSE test data: 19845744.977
# R2 train data: 0.905, R2 test data: 0.872

# %%
plt.figure(figsize=(10,6))

plt.scatter(forest_train_pred,forest_train_pred - y_train,
          c = 'black', marker = 'o', s = 35, alpha = 0.5,
          label = 'Train data')
plt.scatter(forest_test_pred,forest_test_pred - y_test,
          c = 'c', marker = 'o', s = 35, alpha = 0.7,
          label = 'Test data')
plt.xlabel('Predicted values')
plt.ylabel('Tailings')
plt.legend(loc = 'upper left')
plt.hlines(y = 0, xmin = 0, xmax = 60000, lw = 2, color = 'red')
plt.show()

# %%
lr = LinearRegression().fit(x_train,y_train)

y_train_pred = lr.predict(x_train)
y_test_pred = lr.predict(x_test)

print(lr.score(x_test,y_test))
# Out:
# 0.7833463107364539

# %%
from sklearn.preprocessing import PolynomialFeatures


X = df.drop(['charges','region'], axis = 1)
Y = df.charges



quad = PolynomialFeatures (degree = 2)
x_quad = quad.fit_transform(X)

X_train,X_test,Y_train,Y_test = train_test_split(x_quad,Y, random_state = 0)

plr = LinearRegression().fit(X_train,Y_train)

Y_train_pred = plr.predict(X_train)
Y_test_pred = plr.predict(X_test)

print(plr.score(X_test,Y_test))
# Out:
# 0.8849197344147233

# %% [markdown]
# ### Conclusion
# Linear Regression served as a simple benchmark model, providing a reference point for performance evaluation.
#
# Polynomial Regression (degree = 2) extended the linear model by including squared and interaction terms, which improved performance significantly. This demonstrated that nonlinear relationships exist in the dataset.
#
# Ultimately, Random Forest was selected as it provided the best balance between accuracy and generalization.
